# %% [markdown]
# <a href="https://colab.research.google.com/github/24211a6792-PuneetKumarSoni/Deep-Learning--Programs/blob/main/Week_8%2C9%2C10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#week- 8
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
maxlen = 200
embedding_dim = 128
rnn_units = 64
batch_size = 64
epochs = 5

(x_train,y_train),(x_test,y_test) = imdb.load_data(
    num_words=vocab_size)

x_train = pad_sequences(x_train,maxlen=maxlen,padding='post')
x_test = pad_sequences(x_test,maxlen=maxlen,padding='post')

model = models.Sequential([
    layers.Embedding(vocab_size,embedding_dim,
                     input_length=maxlen),
    layers.SimpleRNN(rnn_units),
    layers.Dense(64,activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train,y_train,epochs=epochs,
          batch_size=batch_size,
          validation_split=0.2)

loss,acc = model.evaluate(x_test,y_test,verbose=2)
print("Test Accuracy:",acc)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 34s 101ms/step - accuracy: 0.5163 - loss: 0.6950 - val_accuracy: 0.5348 - val_loss: 0.6820
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 31s 99ms/step - accuracy: 0.5965 - loss: 0.6428 - val_accuracy: 0.5570 - val_loss: 0.6730
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - accuracy: 0.6766 - loss: 0.5048 - val_accuracy: 0.5942 - val_loss: 0.7000
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 31s 98ms/step - accuracy: 0.7196 - loss: 0.4148 - val_accuracy: 0.5832 - val_loss: 0.8234
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 30s 97ms/step - accuracy: 0.7260 - loss: 0.3913 - val_accuracy: 0.5860 - val_loss: 0.9535
# 782/782 - 11s - 14ms/step - accuracy: 0.5842 - loss: 0.9365
# Test Accuracy: 0.5841599702835083

# %%
#week- 9
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
maxlen = 200
embedding_dim = 128
lstm_units = 64
batch_size = 64
epochs = 5

(x_train,y_train),(x_test,y_test) = imdb.load_data(
    num_words=vocab_size)

x_train = pad_sequences(x_train,maxlen=maxlen,padding='post')
x_test = pad_sequences(x_test,maxlen=maxlen,padding='post')

model = models.Sequential([
    layers.Embedding(vocab_size,embedding_dim,
                     input_length=maxlen),
    layers.LSTM(lstm_units),
    layers.Dense(64,activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train,y_train,epochs=epochs,
          batch_size=batch_size,
          validation_split=0.2)

loss,acc = model.evaluate(x_test,y_test,verbose=2)
print("Test Accuracy:",acc)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 81s 252ms/step - accuracy: 0.5985 - loss: 0.6285 - val_accuracy: 0.6400 - val_loss: 0.5757
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 81s 249ms/step - accuracy: 0.6640 - loss: 0.5444 - val_accuracy: 0.6674 - val_loss: 0.5548
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 78s 249ms/step - accuracy: 0.8308 - loss: 0.3921 - val_accuracy: 0.8222 - val_loss: 0.3967
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 78s 248ms/step - accuracy: 0.9147 - loss: 0.2370 - val_accuracy: 0.8634 - val_loss: 0.3368
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 78s 249ms/step - accuracy: 0.9413 - loss: 0.1704 - val_accuracy: 0.8678 - val_loss: 0.3542
# 782/782 - 23s - 29ms/step - accuracy: 0.8603 - loss: 0.3745
# Test Accuracy: 0.8602799773216248

# %%
#week- 10
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
maxlen = 200
embedding_dim = 128
lstm_units = 64
batch_size = 64
epochs = 5

(x_train,y_train),(x_test,y_test) = imdb.load_data(
    num_words=vocab_size)

x_train = pad_sequences(x_train,maxlen=maxlen,padding='post')
x_test = pad_sequences(x_test,maxlen=maxlen,padding='post')

model = models.Sequential([
    layers.Embedding(vocab_size,embedding_dim,
                     input_length=maxlen),
    layers.Bidirectional(layers.LSTM(lstm_units)),
    layers.Dense(64,activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train,y_train,epochs=epochs,
          batch_size=batch_size,
          validation_split=0.2)

loss,acc = model.evaluate(x_test,y_test,verbose=2)
print("Test Accuracy:",acc)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 148s 459ms/step - accuracy: 0.7201 - loss: 0.5302 - val_accuracy: 0.8534 - val_loss: 0.3614
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 145s 462ms/step - accuracy: 0.8899 - loss: 0.2809 - val_accuracy: 0.8760 - val_loss: 0.3266
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 207s 479ms/step - accuracy: 0.9356 - loss: 0.1824 - val_accuracy: 0.8726 - val_loss: 0.3851
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 193s 450ms/step - accuracy: 0.9543 - loss: 0.1325 - val_accuracy: 0.8682 - val_loss: 0.4070
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 143s 455ms/step - accuracy: 0.9734 - loss: 0.0813 - val_accuracy: 0.8736 - val_loss: 0.5058
# 782/782 - 41s - 53ms/step - accuracy: 0.8584 - loss: 0.5552
# Test Accuracy: 0.8583599925041199
